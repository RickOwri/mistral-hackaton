# %%
# !wget "https://storage.googleapis.com/kaggle-data-sets/516764/951745/bundle/archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20240525%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240525T111936Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=..."
# Out:
# The name is too long, 767 chars total.
# Trying to shorten...
# New name is archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com@kaggle-161607.iam.gserviceaccount.com%2F20240525%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240525T111936Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=hos.
# --2024-05-25 13:52:54--  https://storage.googleapis.com/kaggle-data-sets/516764/951745/bundle/archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20240525%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240525T111936Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.253.63.207, 142.250.31.207, 142.251.111.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.253.63.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 166930361 (159M) [application/zip]
# ...

# %%
personality_traits = {
    "EXT": [
        "I am the life of the party.",
        "I don't talk a lot.",
        "I feel comfortable around people.",
        "I keep in the background.",
        "I start conversations.",
        "I have little to say.",
        "I talk to a lot of different people at parties.",
        "I don't like to draw attention to myself.",
        "I don't mind being the center of attention.",
        "I am quiet around strangers."
    ],
    "EST": [
        "I get stressed out easily.",
        "I am relaxed most of the time.",
        "I worry about things.",
        "I seldom feel blue.",
        "I am easily disturbed.",
        "I get upset easily.",
        "I change my mood a lot.",
        "I have frequent mood swings.",
        "I get irritated easily.",
        "I often feel blue."
    ],
    "AGR": [
        "I feel little concern for others.",
        "I am interested in people.",
        "I insult people.",
        "I sympathize with others' feelings.",
        "I am not interested in other people's problems.",
        "I have a soft heart.",
        "I am not really interested in others.",
        "I take time out for others.",
        "I feel others' emotions.",
        "I make people feel at ease."
    ],
    "CSN": [
        "I am always prepared.",
        "I leave my belongings around.",
        "I pay attention to details.",
        "I make a mess of things.",
        "I get chores done right away.",
        "I often forget to put things back in their proper place.",
        "I like order.",
        "I shirk my duties.",
        "I follow a schedule.",
        "I am exacting in my work."
    ],
    "OPN": [
        "I have a rich vocabulary.",
        "I have difficulty understanding abstract ideas.",
        "I have a vivid imagination.",
        "I am not interested in abstract ideas.",
        "I have excellent ideas.",
        "I do not have a good imagination.",
        "I am quick to understand things.",
        "I use difficult words.",
        "I spend time reflecting on things.",
        "I am full of ideas."
    ]
}

# %%
import json

# %%
json.dump(personality_traits, open('big_five.json', 'w'))

# %%
import pandas as pd


pd1 = pd.DataFrame(personality_traits)

# %%
pd1.head(5)
# Out:
#                                  EXT                             EST  \
# 0        I am the life of the party.      I get stressed out easily.
# 1                I don't talk a lot.  I am relaxed most of the time.
# 2  I feel comfortable around people.           I worry about things.
# 3          I keep in the background.             I seldom feel blue.
# 4             I start conversations.          I am easily disturbed.
#
#                                                AGR  \
# 0                I feel little concern for others.
# 1                       I am interested in people.
# 2                                 I insult people.
# 3              I sympathize with others' feelings.
# 4  I am not interested in other people's problems.
#
#                              CSN  \
# 0          I am always prepared.
# 1  I leave my belongings around.
# 2    I pay attention to details.
# 3       I make a mess of things.
# 4  I get chores done right away.
#
# ...

# %%
columns1  = pd1.columns.values.tolist()

# %%
"EXT": [
    {
        "question" : "I am the life of the party.",
        "reponses" : [
            {
                "text" : "Strongly agree",
                "influence" : 2
            },
            {
                "text":
            },
            
        ],
        {
            
        }
    }

# %%
# import pandas as pd

# bigfivetraits  = pd1.columns.values.tolist()
# # Transforming into the desired format
# all_questions = []
# question_data = []
# questions_data = []
# trait_dict = {}
# all_trait_dict = {}
# for trait in bigfivetraits:
#     # print(trait)
#     for question in personality_traits[trait]:
        
#         question_data = {
#             "question": question,
#             "responses": [
#                 {"text": "Strongly disagree", "influence": -2},
#                 {"text": "Disagree", "influence": -1},
#                 {"text": "Neutral", "influence": 0},
#                 {"text": "Agree", "influence": 1},
#                 {"text": "Strongly agree", "influence": 2},
#             ],
#         }
        
        
#     questions_data.append(question_data)
#     trait_dict = {trait : questions_data}
    
#     all_trait_dict.update(trait_dict) 

    

# # for trait, questions in trait_dict.items():
# #     for question in questions:
# #         all_questions.append(question)
# all_trait_dict
# Out:
# {'EXT': [{'question': 'I am quiet around strangers.',
#    'responses': [{'text': 'Strongly disagree', 'influence': -2},
#     {'text': 'Disagree', 'influence': -1},
#     {'text': 'Neutral', 'influence': 0},
#     {'text': 'Agree', 'influence': 1},
#     {'text': 'Strongly agree', 'influence': 2}]},
#   {'question': 'I often feel blue.',
#    'responses': [{'text': 'Strongly disagree', 'influence': -2},
#     {'text': 'Disagree', 'influence': -1},
#     {'text': 'Neutral', 'influence': 0},
#     {'text': 'Agree', 'influence': 1},
#     {'text': 'Strongly agree', 'influence': 2}]},
#   {'question': 'I make people feel at ease.',
#    'responses': [{'text': 'Strongly disagree', 'influence': -2},
#     {'text': 'Disagree', 'influence': -1},
#     {'text': 'Neutral', 'influence': 0},
#     {'text': 'Agree', 'influence': 1},
#     {'text': 'Strongly agree', 'influence': 2}]},
#   {'question': 'I am exacting in my work.',
#    'responses': [{'text': 'Strongly disagree', 'influence': -2},
# ...

# %%
import pandas as pd


def json_transform(dataframe):
    bigfivetraits  = dataframe.columns.values.tolist()
    # Transforming into the desired format
    all_questions = []
    question_data = []
    questions_data = []
    trait_dict = {}
    all_trait_dict = {}
    for trait in bigfivetraits:
        # print(trait)
        for question in personality_traits[trait]:

            question_data = {
                "question": question,
                "responses": [
                    {"text": "Strongly disagree", "influence": -2},
                    {"text": "Disagree", "influence": -1},
                    {"text": "Neutral", "influence": 0},
                    {"text": "Agree", "influence": 1},
                    {"text": "Strongly agree", "influence": 2},
                ],
            }

        questions_data.append(question_data)
        trait_dict = {trait : questions_data}

        all_trait_dict.update(trait_dict) 



    # for trait, questions in trait_dict.items():
    #     for question in questions:
    #         all_questions.append(question)
    return all_trait_dict

json_transform(pd1)
# Out:
# {'EXT': [{'question': 'I am quiet around strangers.',
#    'responses': [{'text': 'Strongly disagree', 'influence': -2},
#     {'text': 'Disagree', 'influence': -1},
#     {'text': 'Neutral', 'influence': 0},
#     {'text': 'Agree', 'influence': 1},
#     {'text': 'Strongly agree', 'influence': 2}]},
#   {'question': 'I often feel blue.',
#    'responses': [{'text': 'Strongly disagree', 'influence': -2},
#     {'text': 'Disagree', 'influence': -1},
#     {'text': 'Neutral', 'influence': 0},
#     {'text': 'Agree', 'influence': 1},
#     {'text': 'Strongly agree', 'influence': 2}]},
#   {'question': 'I make people feel at ease.',
#    'responses': [{'text': 'Strongly disagree', 'influence': -2},
#     {'text': 'Disagree', 'influence': -1},
#     {'text': 'Neutral', 'influence': 0},
#     {'text': 'Agree', 'influence': 1},
#     {'text': 'Strongly agree', 'influence': 2}]},
#   {'question': 'I am exacting in my work.',
#    'responses': [{'text': 'Strongly disagree', 'influence': -2},
# ...

# %%
import pandas as pd


def json_transform(dataframe):
    bigfivetraits  = dataframe.columns.values.tolist()
    # Transforming into the desired format
    all_questions = []
    question_data = []
    questions_data = []
    trait_dict = {}
    all_trait_dict = {}
    for trait in bigfivetraits:
        # print(trait)
        for question in personality_traits[trait]:

            question_data = {
                "question": question,
                "responses": [
                    {"text": "Strongly disagree", "influence": -2},
                    {"text": "Disagree", "influence": -1},
                    {"text": "Neutral", "influence": 0},
                    {"text": "Agree", "influence": 1},
                    {"text": "Strongly agree", "influence": 2},
                ],
            }

        questions_data.append(question_data)
        trait_dict = {trait : questions_data}

        all_trait_dict.update(trait_dict) 



    # for trait, questions in trait_dict.items():
    #     for question in questions:
    #         all_questions.append(question)
    return all_trait_dict

# %%
text_template = """Reply to this question with an answer from the given list.
Use the associated number to reply. If more context is needed, invent one for yourself using your inner voice.
Never question the assignement. ONLY REPLY WITH THE NUMBER AND NOTHING ELSE.

Question: {question}

Answers:
{answers}
"""
